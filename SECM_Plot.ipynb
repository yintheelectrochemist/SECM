# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# read csv
file_src = 'c:/CHI/Data/matlab/ac_secm_o_1.txt'
my_data = np.genfromtxt(file_src, delimiter=',',skip_header=1)
x = my_data[:,0]
y = my_data[:,1]
z = my_data[:,2]
# prepare to reshape the matrix
size = np.size(np.unique(X))
X = x.reshape(size, size)
Y = y.reshape(size, size)
Z = z.reshape(size, size)
# prepare to 3d plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z,cmap='jet', shade = 1)
fig.colorbar(surf, shrink=1, aspect=10)
ax.set_xlabel('X / \u00B5m')
ax.set_ylabel('Y / \u00B5m')
ax.set_zlabel('Z / A')
plt.show()
